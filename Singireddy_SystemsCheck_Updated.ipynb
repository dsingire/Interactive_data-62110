# %% [markdown]
# # Systems Check

# %% [markdown]
# #### divya

# %% [markdown]
# **singireddy**

# %% [markdown]
# *8/20/2024*

# %% [markdown]
# Objectives to aim in this class:
#
# 1. **Effective Analysis of Complex Real-World Data**: Showcase your *data analysis* competence by developing your ability to glean significant insights from unstructured real-world data.
#
# 2. **Implementation of Regression-Based Statistical Learning Techniques**: Put your *data analysis* expertise to the test by learning how to use and comprehend regression-based statistical learning techniques.
#
# 3. **Ethical Handling of Social and Behavioral Data**: Pay close attention to privacy, bias, and power dynamics as you work to establish a solid ethical framework for obtaining and using social and behavioral data in an ethical manner.

# %% [markdown]
# ![image.png](attachment:040b0c80-9b60-4671-8a3e-cc81a4c8a164.png)

# %%
# variable assignment
x = 3
print(x)
# Out:
# 3

# %%
my_list = [2,3,4,5]
my_list
# Out:
# [2, 3, 4, 5]

# %%
my_list = ['now', 'see', 'this']

# %%
# a function with print statement
my_name = 'Divya'

# %%
def display_name(x):
    print(x)

# %%
display_name(my_name)
# Out:
# Divya

# %%
# a function with return statement
def change_name(x):
    new_name = x + 'new'
    return new_name

# %%
changed_name = change_name('Divya')
changed_name
# Out:
# 'Divyanew'
